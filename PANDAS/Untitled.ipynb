# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([10,20,30,40,50])
y = np.array([1,5,6,3,2])
plt.plot(x,y)
plt.show()

# %%
# Create a Pandas Series from a dictionary 
calories = {"day1": 420, "day2": 380, "day3": 390,"day1":500}
#myvar = pd.Series(calories)
#print("Pandas Series:\n", myvar)
for i in range(5):
    for j in range(
# Out:
# 1
# 23
# 456
# 78910
# 1112131415

# %%
mydataset = {
  'name': ["rakesh", "mani", "vinay", "manohar", "shruthihussan", "kajal", "thammanna", "samatha"],
  'gender': ["male", "male", "male", "male", , 4, 5, 2]
}

grouped = .groupby('class')
mean_passings = grouped['passings'].mean()
print(mean_pass)
